# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("G:/ProjetoData/ForcaAereaBrasileira/ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              49474               49474                 ACIDENTE
# 1              40310               40310                INCIDENTE
# 2              40207               40207                INCIDENTE
# 3              39913               39913          INCIDENTE GRAVE
# 4              40273               40273                INCIDENTE
# 5              40295               40295                INCIDENTE
# 6              41579               41579                INCIDENTE
# 7              41976               41976                INCIDENTE
# 8              43711               43711                INCIDENTE
# 9              43702               43702                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  ÁGUAS INTERNACIONAIS            **                 ****     2013-09-02
# 1       CRUZEIRO DO SUL            AC                 SBCZ     2010-01-18
# 2       CRUZEIRO DO SUL            AC                 SBCZ     2010-02-06
# 3            RIO BRANCO            AC                 SBRB     2010-03-10
# 4            RIO BRANCO            AC                 SBRB     2010-03-10
# 5            RIO BRANCO            AC                 SBRB     2010-04-11
# 6   SANTA ROSA DO PURUS            AC                 ****     2010-06-09
# 7            RIO BRANCO            AC                 ****     2010-07-23
# 8            RIO BRANCO            AC                 ****     2011-01-20
# 9            RIO BRANCO            AC                 ****     2011-01-21
#
#   ocorrencia_hora  total_aeronaves_envolvidas
# 0        02:54:00                           1
# 1        19:32:00                           1
# 2        22:30:00                           1
# 3        06:17:00                           1
# 4        14:30:00                           1
# 5        19:20:00                           1
# 6        13:55:00                           1
# 7        08:08:00                           1
# 8        17:58:00                           1
# 9        17:35:00                           1

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo":pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo":pa.Column(pa.String),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_aeronaves_envolvidas":pa.Column(pa.Int)
        
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 49474               49474                 ACIDENTE
# 1                 40310               40310                INCIDENTE
# 2                 40207               40207                INCIDENTE
# 3                 39913               39913          INCIDENTE GRAVE
# 4                 40273               40273                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79301               79301                 ACIDENTE
# 5748              79484               79484                 ACIDENTE
# 5749              79636               79636                 ACIDENTE
# 5750              79690               79690          INCIDENTE GRAVE
# 5751              79757               79757          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     ÁGUAS INTERNACIONAIS            **                 ****     2013-09-02
# 1          CRUZEIRO DO SUL            AC                 SBCZ     2010-01-18
# 2          CRUZEIRO DO SUL            AC                 SBCZ     2010-02-06
# 3               RIO BRANCO            AC                 SBRB     2010-03-10
# 4               RIO BRANCO            AC                 SBRB     2010-03-10
# ...                    ...           ...                  ...            ...
# 5747    BREJINHO DE NAZARÉ            TO                 ****     2020-04-18
# 5748                GURUPI            TO                 SWGI     2020-08-08
# 5749                PALMAS            TO                 ****     2020-10-29
# 5750        PORTO NACIONAL            TO                 SWEJ     2020-11-24
# 5751     LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
#
#      ocorrencia_hora  total_aeronaves_envolvidas
# 0           02:54:00                           1
# 1           19:32:00                           1
# 2           22:30:00                           1
# 3           06:17:00                           1
# 4           14:30:00                           1
# ...              ...                         ...
# 5747        13:30:00                           1
# 5748        13:20:00                           1
# 5749        20:00:00                           1
# 5750        20:00:00                           1
# 5751        18:30:00                           1
#
# [5752 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                      int64
# codigo_ocorrencia2                     int64
# ocorrencia_classificacao              object
# ocorrencia_cidade                     object
# ocorrencia_uf                         object
# ocorrencia_aerodromo                  object
# ocorrencia_dia                datetime64[ns]
# ocorrencia_hora                       object
# total_aeronaves_envolvidas             int64
# dtype: object

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0        9
# 1        1
# 2        2
# 3        3
# 4        3
#         ..
# 5747     4
# 5748     8
# 5749    10
# 5750    11
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %% [raw]
# pip install pandera
