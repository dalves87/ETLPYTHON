# %%
import pandas as pd

# %% [markdown]
# # Carregar Meus Dados csv

# %%
df = pd.read_csv("G:/ProjetoData/ForcaAereaBrasileira/ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              77289               77289                INCIDENTE
# 1              46349               46349                INCIDENTE
# 2              65572               65572                INCIDENTE
# 3              78635               78635                INCIDENTE
# 4              79449               79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                 ****     2020-07-21
#
#   ocorrencia_hora  total_aeronaves_envolvidas  total_recomendacoes
# ...

# %% [markdown]
# ## Localizar um dado pelo índice

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'GOIÂNIA'

# %% [markdown]
# ## Localizar os registros de 1 à 3 pelo índice

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              46349               46349                INCIDENTE
# 2              65572               65572                INCIDENTE
# 3              78635               78635                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1           GOIÂNIA            GO                 SBGO     2012-08-23
# 2           GOIÂNIA            GO                 SBGO     2016-08-25
# 3         OURO FINO            MG                 SNOF     2019-04-04
#
#   ocorrencia_hora  total_aeronaves_envolvidas
# 1        00:00:00                           1
# 2        00:00:00                           1
# 3        00:00:00                           1

# %% [markdown]
# ## Localizar os registros 10 e 40 pelo índice

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              78264               78264                INCIDENTE
# 40              50374               50374                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    RIO DE JANEIRO            RJ                 SBGL     2018-10-23
# 40    RIO DE JANEIRO            RJ                 SBGL     2013-12-02
#
#    ocorrencia_hora  total_aeronaves_envolvidas
# 10        00:00:00                           1
# 40        00:27:00                           1

# %% [markdown]
# ## Localizar todas as cidades pelo índice

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0       VITÓRIA DA CONQUISTA
# 1                    GOIÂNIA
# 2                    GOIÂNIA
# 3                  OURO FINO
# 4                 PATROCÍNIO
#                 ...
# 5747            JUIZ DE FORA
# 5748                LONDRINA
# 5749                 CONFINS
# 5750          RIO DE JANEIRO
# 5751                 CORUMBÁ
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %% [markdown]
# ## Verificar se o campo 'codigo_ocorrencia' é único

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# ## Alterar o índice para 'codigo_ocorrencia'

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %% [markdown]
# ## Lista os 5 primeiros registros

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 77289                           77289                INCIDENTE
# 46349                           46349                INCIDENTE
# 65572                           65572                INCIDENTE
# 78635                           78635                INCIDENTE
# 79449                           79449                 ACIDENTE
#
#                       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 77289              VITÓRIA DA CONQUISTA            BA                 SBQV
# 46349                           GOIÂNIA            GO                 SBGO
# 65572                           GOIÂNIA            GO                 SBGO
# 78635                         OURO FINO            MG                 SNOF
# 79449                        PATROCÍNIO            MG                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_aeronaves_envolvidas
# ...

# %% [markdown]
# ## Localizar um registro pelo índice

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                          40324
# ocorrencia_classificacao                INCIDENTE
# ocorrencia_cidade                         PELOTAS
# ocorrencia_uf                                  RS
# ocorrencia_aerodromo                         SBPK
# ocorrencia_dia                2010-01-05 00:00:00
# ocorrencia_hora                          19:25:00
# total_aeronaves_envolvidas                      1
# Name: 40324, dtype: object

# %% [markdown]
# ## Remover o índice criado

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao     ocorrencia_cidade  \
# 0               77289                INCIDENTE  VITÓRIA DA CONQUISTA
# 1               46349                INCIDENTE               GOIÂNIA
# 2               65572                INCIDENTE               GOIÂNIA
# 3               78635                INCIDENTE             OURO FINO
# 4               79449                 ACIDENTE            PATROCÍNIO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            BA                 SBQV     2017-11-28        00:00:00
# 1            GO                 SBGO     2012-08-23        00:00:00
# 2            GO                 SBGO     2016-08-25        00:00:00
# 3            MG                 SNOF     2019-04-04        00:00:00
# 4            MG                 ****     2020-07-21        00:00:00
#
#    total_aeronaves_envolvidas
# 0                           1
# 1                           1
# 2                           1
# ...

# %% [markdown]
# ## Alterar um registro de uma coluna pelo índice

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %% [markdown]
# ## Alterar um registro pelo índice

# %%
df.loc[1] = 20

# %% [markdown]
# ## Alterar todas as colunas pelo índice

# %%
df.loc[:,'total_recomendacoes'] = 10

# %% [markdown]
# ## Listar o dataFrame

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao     ocorrencia_cidade  \
# 0                  77289                INCIDENTE  VITÓRIA DA CONQUISTA
# 1                     20                       20                    20
# 2                  65572                INCIDENTE               GOIÂNIA
# 3                  78635                INCIDENTE             OURO FINO
# 4                  79449                 ACIDENTE            PATROCÍNIO
# ...                  ...                      ...                   ...
# 5747               41574                INCIDENTE          JUIZ DE FORA
# 5748               65490                 ACIDENTE              LONDRINA
# 5749               52596                 ACIDENTE               CONFINS
# 5750               77940                INCIDENTE        RIO DE JANEIRO
# 5751               78823                INCIDENTE               CORUMBÁ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# ## Fazer o bkp de uma coluna

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao     ocorrencia_cidade  \
# 0                  77289                INCIDENTE  VITÓRIA DA CONQUISTA
# 1                     20                       20                    20
# 2                  65572                INCIDENTE               GOIÂNIA
# 3                  78635                INCIDENTE             OURO FINO
# 4                  79449                 ACIDENTE            PATROCÍNIO
# ...                  ...                      ...                   ...
# 5747               41574                INCIDENTE          JUIZ DE FORA
# 5748               65490                 ACIDENTE              LONDRINA
# 5749               52596                 ACIDENTE               CONFINS
# 5750               77940                INCIDENTE        RIO DE JANEIRO
# 5751               78823                INCIDENTE               CORUMBÁ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# ## Alterar todas as ocorrencias de uma coluna com um where

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao     ocorrencia_cidade  \
# 0                  77289                INCIDENTE  VITÓRIA DA CONQUISTA
# 1                     20                       20                    20
# 2                  65572                INCIDENTE               GOIÂNIA
# 3                  78635                INCIDENTE             OURO FINO
# 4                  79449                 ACIDENTE            PATROCÍNIO
# ...                  ...                      ...                   ...
# 5747               41574                INCIDENTE          JUIZ DE FORA
# 5748               65490                 ACIDENTE              LONDRINA
# 5749               52596                 ACIDENTE               CONFINS
# 5750               77940                INCIDENTE        RIO DE JANEIRO
# 5751               78823                INCIDENTE               CORUMBÁ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# ## Lista registros da UF = SP

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 14                 78977                    GRAVE        SÃO CARLOS
# 18                 66477                    GRAVE         SÃO PAULO
# 22                 46716                    GRAVE          CAMPINAS
# 23                 66395                    GRAVE         GUARULHOS
# 26                 66860                    GRAVE         SÃO PAULO
# ...                  ...                      ...               ...
# 5731               78942                    GRAVE         GUARULHOS
# 5734               49623                    GRAVE          CAMPINAS
# 5739               40314                    GRAVE         SÃO PAULO
# 5740               79249                    GRAVE          CAMPINAS
# 5746               44902                    GRAVE           JUNDIAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 77289               77289                INCIDENTE
# 1                 46349               46349                INCIDENTE
# 2                 65572               65572                INCIDENTE
# 3                 78635               78635                INCIDENTE
# 4                 79449               79449                 ACIDENTE
# ...                 ...                 ...                      ...
# 5747              41574               41574                INCIDENTE
# 5748              65490               65490                 ACIDENTE
# 5749              52596               52596                 ACIDENTE
# 5750              77940               77940                INCIDENTE
# 5751              78823               78823                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              77289               77289                INCIDENTE
# 1              46349               46349                INCIDENTE
# 2              65572               65572                INCIDENTE
# 3              78635               78635                INCIDENTE
# 4              79449               79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                 ****     2020-07-21
#
#   ocorrencia_hora  total_aeronaves_envolvidas
# 0        00:00:00                           1
# ...

# %% [markdown]
# ## Replace de '***' para NA

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              77289               77289                INCIDENTE
# 1              46349               46349                INCIDENTE
# 2              65572               65572                INCIDENTE
# 3              78635               78635                INCIDENTE
# 4              79449               79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                 <NA>     2020-07-21
#
#   ocorrencia_hora  total_aeronaves_envolvidas
# 0        00:00:00                           1
# ...

# %% [markdown]
# ## Replace de uma lista de valores para NA

# %%
df.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5747              41574               41574                INCIDENTE
# 5748              65490               65490                 ACIDENTE
# 5749              52596               52596                 ACIDENTE
# 5750              77940               77940                INCIDENTE
# 5751              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5747      JUIZ DE FORA            MG                 <NA>     2010-05-14
# 5748          LONDRINA            PR                 SBLO     2016-07-31
# 5749           CONFINS            MG                 SBCF     2014-09-25
# 5750    RIO DE JANEIRO            RJ                 SBGL     2018-06-07
# 5751           CORUMBÁ            MS                 <NA>     2017-07-09
#
#      ocorrencia_hora  total_aeronaves_envolvidas  total_recomendacoes
# ...

# %% [markdown]
# ## Verifica os dados não informados

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                0
# codigo_ocorrencia2               0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    1
# ocorrencia_aerodromo          2349
# ocorrencia_dia                   0
# ocorrencia_hora                  1
# total_aeronaves_envolvidas       0
# total_recomendacoes              0
# dtype: int64

# %% [markdown]
# ## Verifica os dados nulo informados

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                0
# codigo_ocorrencia2               0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    1
# ocorrencia_aerodromo          2349
# ocorrencia_dia                   0
# ocorrencia_hora                  1
# total_aeronaves_envolvidas       0
# total_recomendacoes              0
# dtype: int64

# %% [markdown]
# ## Alterar os dados nulos e não informados para 10

# %%
df.fillna(10, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia             0
# codigo_ocorrencia2            0
# ocorrencia_classificacao      0
# ocorrencia_cidade             0
# ocorrencia_uf                 0
# ocorrencia_aerodromo          0
# ocorrencia_dia                0
# ocorrencia_hora               0
# total_aeronaves_envolvidas    0
# total_recomendacoes           0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              77289               77289                INCIDENTE
# 1              46349               46349                INCIDENTE
# 2              65572               65572                INCIDENTE
# 3              78635               78635                INCIDENTE
# 4              79449               79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                   10     2020-07-21
#
#   ocorrencia_hora  total_aeronaves_envolvidas  total_recomendacoes
# ...

# %% [markdown]
# ## Verificar os dados que foram alterados

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                0
# codigo_ocorrencia2               0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    1
# ocorrencia_aerodromo          2349
# ocorrencia_dia                   0
# ocorrencia_hora                  1
# total_aeronaves_envolvidas       0
# total_recomendacoes              2
# dtype: int64

# %% [markdown]
# ## Se precisar voltar alteração

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                0
# codigo_ocorrencia2               0
# ocorrencia_classificacao         0
# ocorrencia_cidade                0
# ocorrencia_uf                    1
# ocorrencia_aerodromo          2349
# ocorrencia_dia                   0
# ocorrencia_hora                  1
# total_aeronaves_envolvidas       0
# total_recomendacoes              0
# dtype: int64

# %% [markdown]
# ## Realizar um bkp

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             77289              77289                INCIDENTE
# 1             46349              46349                INCIDENTE
# 2             65572              65572                INCIDENTE
# 3             78635              78635                INCIDENTE
# 4             79449              79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                 <NA>     2020-07-21
#
#   ocorrencia_hora total_aeronaves_envolvidas  total_recomendacoes  \
# ...

# %% [markdown]
# ## Remover uma coluna

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0             77289              77289                INCIDENTE
# 1             46349              46349                INCIDENTE
# 2             65572              65572                INCIDENTE
# 3             78635              78635                INCIDENTE
# 4             79449              79449                 ACIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0  VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# 1               GOIÂNIA            GO                 SBGO     2012-08-23
# 2               GOIÂNIA            GO                 SBGO     2016-08-25
# 3             OURO FINO            MG                 SNOF     2019-04-04
# 4            PATROCÍNIO            MG                 <NA>     2020-07-21
#
#   ocorrencia_hora total_aeronaves_envolvidas  total_recomendacoes
# 0        00:00:00                          1                    0
# ...

# %% [markdown]
# ## Excluir todos os valores não informados a linha toda

# %%
df.dropna()
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                77289              77289                INCIDENTE
# 1                46349              46349                INCIDENTE
# 2                65572              65572                INCIDENTE
# 3                78635              78635                INCIDENTE
# 7                66378              66378                 ACIDENTE
# ...                ...                ...                      ...
# 5745             42486              42486                INCIDENTE
# 5746             44902              44902                INCIDENTE
# 5748             65490              65490                 ACIDENTE
# 5749             52596              52596                 ACIDENTE
# 5750             77940              77940                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# ...

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                77289              77289                INCIDENTE
# 1                46349              46349                INCIDENTE
# 2                65572              65572                INCIDENTE
# 3                78635              78635                INCIDENTE
# 4                79449              79449                 ACIDENTE
# ...                ...                ...                      ...
# 5747             41574              41574                INCIDENTE
# 5748             65490              65490                 ACIDENTE
# 5749             52596              52596                 ACIDENTE
# 5750             77940              77940                INCIDENTE
# 5751             78823              78823                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# ...

# %% [markdown]
# ## Excluir as linhas com where

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                77289              77289                INCIDENTE
# 1                46349              46349                INCIDENTE
# 2                65572              65572                INCIDENTE
# 3                78635              78635                INCIDENTE
# 4                79449              79449                 ACIDENTE
# ...                ...                ...                      ...
# 5747             41574              41574                INCIDENTE
# 5748             65490              65490                 ACIDENTE
# 5749             52596              52596                 ACIDENTE
# 5750             77940              77940                INCIDENTE
# 5751             78823              78823                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# ...

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                77289              77289                INCIDENTE
# 1                46349              46349                INCIDENTE
# 2                65572              65572                INCIDENTE
# 3                78635              78635                INCIDENTE
# 4                79449              79449                 ACIDENTE
# ...                ...                ...                      ...
# 5747             41574              41574                INCIDENTE
# 5748             65490              65490                 ACIDENTE
# 5749             52596              52596                 ACIDENTE
# 5750             77940              77940                INCIDENTE
# 5751             78823              78823                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# ...

# %% [markdown]
# ## retirar valores dublicados

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                77289              77289                INCIDENTE
# 1                46349              46349                INCIDENTE
# 2                65572              65572                INCIDENTE
# 3                78635              78635                INCIDENTE
# 4                79449              79449                 ACIDENTE
# ...                ...                ...                      ...
# 5747             41574              41574                INCIDENTE
# 5748             65490              65490                 ACIDENTE
# 5749             52596              52596                 ACIDENTE
# 5750             77940              77940                INCIDENTE
# 5751             78823              78823                INCIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0     VITÓRIA DA CONQUISTA            BA                 SBQV     2017-11-28
# ...
